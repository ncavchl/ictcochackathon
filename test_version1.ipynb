# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np

# %%
image = cv2.imread("201804112600031010.jpg",cv2.IMREAD_COLOR)

# %%
image.shape
# Out:
# (4694, 7321, 3)

# %%
GB = cv2.GaussianBlur(image,(11,11),0)

plt.imshow(GB)

# %%
gray = cv2.cvtColor(GB, cv2.COLOR_BGR2GRAY)

plt.imshow(gray)

# %%
canny = cv2.Canny(gray, 30, 150)

plt.imshow(canny)

# %%
ret, img_binary = cv2.threshold(canny, 127, 255, 0)
plt.imshow(img_binary)

# %%
contours, hierarchy = cv2.findContours(img_binary, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# %%
res_list = []

# %%
for cnt in contours:
    #cv2.drawContours(roi, [cnt], 0, (255, 0, 0), 3)  # blue
    if cv2.contourArea(cnt) < 1500: 
        cv2.drawContours(img_binary, [cnt], -1, 255, -1)
        x,y,w,h = cv2.boundingRect(cnt)
        if w>70 and h>70:
            res_list.append(image[y: y + 70,x: x + 70])
            #plt.imshow(image[y: y + 50, x: x + 50])

# %%
plt.imshow(res_list[8])

# %%
len(res_list)
# Out:
# 500
