# %%
import cv2
from matplotlib import pyplot as plt 
import numpy as np

# %% [markdown]
# ### 0 도로
# ### 1 옥상
# ### 2 옥상 + 화단 or 불법
# ### 10 모름

# %%
image = cv2.imread("./test3/test"+str(n)+".png",cv2.IMREAD_COLOR)

# %%
plt.rcParams["figure.figsize"] = (5,5)

# %%
n=978

# %%
# lable = []
while(True):
    image = cv2.imread("./test3/test"+str(n)+".png",cv2.IMREAD_COLOR)
    print(str("./test3/test"+str(n)+".png") + " 진행중")
    try:
        plt.imshow(image)
        plt.show()
    except Exception as e:
        print(e)
        n=n+1
        continue
    
    x = int(input('yes or no : '))
    if x > 100:
        break;
    else:
        if x in [0,1,2,10]:
            try:
                plt.imsave('./분류/'+str(x)+'/'+'test'+str(n)+".png",image)
                print('./분류/'+str(x)+'/'+'test'+str(n)+".png 에 드감")
            except Exception as e:
                print(str("./test3/test"+str(idx)+".png") + " 에러?")
                pass
            n=n+1
        else:
            pass
# Out:
# ./test3/test994.png 진행중
# yes or no : 1
# ./분류/1/test994.png 에 드감
# ./test3/test995.png 진행중
# yes or no : 0
# ./분류/0/test995.png 에 드감
# ./test3/test996.png 진행중
# yes or no : 1
# ./분류/1/test996.png 에 드감
# ./test3/test997.png 진행중
# yes or no : 1
# ./분류/1/test997.png 에 드감
# ./test3/test998.png 진행중
# yes or no : 0
# ./분류/0/test998.png 에 드감
# ./test3/test999.png 진행중
# yes or no : 1
# ./분류/1/test999.png 에 드감
# ./test3/test1000.png 진행중
# Image data cannot be converted to float
# ./test3/test1001.png 진행중
# yes or no : 1
# ./분류/1/test1001.png 에 드감
# ./test3/test1002.png 진행중
# yes or no : 1
# ./분류/1/test1002.png 에 드감
# ./test3/test1003.png 진행중
# yes or no : 1
# ./분류/1/test1003.png 에 드감
# ./test3/test1004.png 진행중
# yes or no : 1
# ./분류/1/test1004.png 에 드감
# ./test3/test1005.png 진행중
# yes or no :
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-6270c85a5466> in <module>
# ...

# %%
len(lable)

# %%
with open('test_text.txt', 'w') as f:
    for item in lable:
        f.write("%s\n" % item)
